# %%
# summarize the horse colic dataset
from pandas import read_csv

# %%
# load dataset
dataframe = read_csv('horse-colic.csv', header=None, na_values='?')

# %%
# summarize the first few rows
print(dataframe.head())
# Out:
#         0    1                2                   3      4                 5   \
# 0  surgery  Age  Hospital Number  rectal temperature  pulse  respiratory rate
# 1        2    1           530101                38.5     66                28
# 2        1    1           534817                39.2     88                20
# 3        2    1           530334                38.3     40                24
# 4        1    9          5290409                39.1    164                84
#
#                            6                 7                 8   \
# 0  temperature of extremities  peripheral pulse  mucous membranes
# 1                           3                 3               NaN
# 2                         NaN               NaN                 4
# 3                           1                 1                 3
# 4                           4                 1                 6
#
#                       9   ...                  18             19  \
# 0  capillary refill time  ...  packed cell volume  total protein
# 1                      2  ...                  45            8.4
# 2                      1  ...                  50             85
# 3                      1  ...                  33            6.7
# 4                      2  ...                  48            7.2
#
#                             20                           21       22  \
# 0  abdominocentesis appearance  abdomcentesis total protein  outcome
# 1                          NaN                          NaN        2
# 2                            2                            2        3
# 3                          NaN                          NaN        1
# 4                            3                          5.3        2
#
#                 23                24                25                26  \
# 0  surgical lesion  type of lesion 1  type of lesion 2  type of lesion 3
# 1                2             11300                 0                 0
# 2                2              2208                 0                 0
# 3                2                 0                 0                 0
# 4                1              2208                 0                 0
#
#         27
# 0  cp_data
# 1        2
# 2        2
# 3        1
# 4        1
#
# [5 rows x 28 columns]

# %%
# summarize the number of rows with missing values for each column
for i in range(dataframe.shape[1]):
    # count number of rows with missing values
    n_miss = dataframe[[i]].isnull().sum()
    perc = n_miss / dataframe.shape[0] * 100
    print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# Out:
# > 0, MISSING: 1 (0.3%)
# > 1, MISSING: 0 (0.0%)
# > 2, MISSING: 0 (0.0%)
# > 3, MISSING: 60 (19.9%)
# > 4, MISSING: 24 (8.0%)
# > 5, MISSING: 58 (19.3%)
# > 6, MISSING: 56 (18.6%)
# > 7, MISSING: 69 (22.9%)
# > 8, MISSING: 47 (15.6%)
# > 9, MISSING: 32 (10.6%)
# > 10, MISSING: 55 (18.3%)
# > 11, MISSING: 44 (14.6%)
# > 12, MISSING: 56 (18.6%)
# > 13, MISSING: 104 (34.6%)
# > 14, MISSING: 106 (35.2%)
# > 15, MISSING: 247 (82.1%)
# > 16, MISSING: 102 (33.9%)
# > 17, MISSING: 118 (39.2%)
# > 18, MISSING: 29 (9.6%)
# > 19, MISSING: 33 (11.0%)
# > 20, MISSING: 165 (54.8%)
# > 21, MISSING: 198 (65.8%)
# > 22, MISSING: 1 (0.3%)
# > 23, MISSING: 0 (0.0%)
# > 24, MISSING: 0 (0.0%)
# > 25, MISSING: 0 (0.0%)
# > 26, MISSING: 0 (0.0%)
# > 27, MISSING: 0 (0.0%)
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
# /tmp/ipykernel_565/4198858015.py:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   print('> %d, MISSING: %d (%.1f%%)' % (i, n_miss, perc))
